# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # With iris Data set

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

x = df[iris.feature_names[0]]
y = df[iris.feature_names[1]]

plt.plot(x[:50], y[:50])
plt.title("Line Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

x = df[iris.feature_names[0]]
y = df[iris.feature_names[1]]

plt.scatter(x, y, c=iris.target)
plt.title("Scatter Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

means = df.groupby('species')[iris.feature_names[0]].mean()
plt.bar(means.index, means.values)
plt.title("Bar Chart - Mean Sepal Length")
plt.ylabel("Length (cm)")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

plt.hist(df[iris.feature_names[0]], bins=20, color='skyblue', edgecolor='black')
plt.title("Histogram")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

data = [df[df['species'] == sp][iris.feature_names[0]] for sp in iris.target_names]
plt.boxplot(data, tick_labels=iris.target_names)
plt.title("Box Plot - Sepal Length by Species")
plt.ylabel("Length (cm)")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
species = pd.Series(iris.target).map(dict(enumerate(iris.target_names)))

counts = species.value_counts()
plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%')
plt.title("Pie Chart - Species Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

area_data = df[iris.feature_names[:3]].iloc[:20].cumsum()
plt.stackplot(range(len(area_data)), area_data.values.T, labels=iris.feature_names[:3])
plt.legend()
plt.title("Area Plot - Cumulative Features")
plt.xlabel("Sample Index")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

means = df.groupby('species')[iris.feature_names[0]].mean()
stds = df.groupby('species')[iris.feature_names[0]].std()

plt.errorbar(means.index, means.values, yerr=stds.values, fmt='o', capsize=5)
plt.title("Error Bar Plot - Sepal Length")
plt.ylabel("Length (cm)")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

plt.step(df[iris.feature_names[0]][:30], df[iris.feature_names[1]][:30], where='mid')
plt.title("Step Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

plt.stem(df[iris.feature_names[0]][:20], df[iris.feature_names[1]][:20])
plt.title("Stem Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

corr = df.corr()
fig, ax = plt.subplots()
im = ax.imshow(corr, cmap='viridis')

ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns, rotation=90)
ax.set_yticklabels(corr.columns)
plt.colorbar(im)
plt.title("Heatmap - Feature Correlation")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
from scipy.stats import gaussian_kde
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

data = df[iris.feature_names[0]]
kde = gaussian_kde(data)
x_vals = np.linspace(min(data), max(data), 200)
y_vals = kde(x_vals)

plt.plot(x_vals, y_vals)
plt.fill_between(x_vals, y_vals, alpha=0.5)
plt.title("KDE Plot - Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Density")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
from scipy.stats import gaussian_kde
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

for i, sp in enumerate(iris.target_names):
    d = df[df['species'] == sp][iris.feature_names[0]]
    kde = gaussian_kde(d)
    x = np.linspace(min(d), max(d), 100)
    y = kde(x)
    plt.fill_betweenx(x, i - y, i + y, alpha=0.6)

plt.xticks(range(3), iris.target_names)
plt.title("Violin Plot - Sepal Length")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

for i, sp in enumerate(iris.target_names):
    d = df[df['species'] == sp][iris.feature_names[0]]
    jitter = np.random.uniform(-0.1, 0.1, size=len(d))
    plt.scatter(np.full_like(d, i) + jitter, d, alpha=0.6)

plt.xticks(range(3), iris.target_names)
plt.title("Swarm Plot - Sepal Length")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

for i, sp in enumerate(iris.target_names):
    d = df[df['species'] == sp][iris.feature_names[0]]
    plt.scatter(np.full_like(d, i), d, alpha=0.6)

plt.xticks(range(3), iris.target_names)
plt.title("Strip Plot - Sepal Length")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

data = df[iris.feature_names[0]]
plt.plot(data, np.zeros_like(data), '|', markersize=10)
plt.title("Rug Plot - Sepal Length")
plt.yticks([])
plt.show()
